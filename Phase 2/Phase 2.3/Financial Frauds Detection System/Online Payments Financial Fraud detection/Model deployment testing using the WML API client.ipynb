# %% [markdown]
# # Commands to generate the API key tokens
# Run the below command and copy the IBM IAM access token generated which is validate for only 60 mins.

# %%
# !curl -k -X POST --header "Content-Type: applx-www-form-urlencoded" --header "Accept: application/json" --data-urlencode "grant_type=urn:ibm:params:oauth:grant-type:apikey" --data-urlencode "apikey=abufD5so3Cxq46oW7LHsDBdwI3ESFQS-YUikMUh8VtaS" "https://iam.cloud.ibm.com/identity/token"
# Out:
# {"access_token":"eyJraWQiOiIyMDIwMDUyNTE4MzAiLCJhbGciOiJSUzI1NiJ9.....GzwhRp8q4S6i8DBUDr7K19iu5xUc86NdlvrQnIFbLQecYo1H18TWojD02Gh0hBcC9nDA-uW2AKVPmcv1aaHaqNbbfiHIkCmbqqZo2XTsuxHBjfbyhRuHBAOg8MBelHxvWc8c2z6H2I_lbix7VPBhG8iYH4Hx7TzQFCrZOq1RjHHogdCABoUMaRY9SrXufimjTIjoajKKkzS_t4ICKWjL-_DsF4QOpAUNAu6h4JBnJ-bIFg4PbpbVkfG4-4m2b-RPUmBv-6aeODHeCzBu_vKOxOWq8X8DaEkFKeOQJBC8Evtktk-HvGEe_umTaHwfhWlAUOnxwtyPFBIHdze49Z-Qpw","refresh_token":"OKDACmi4pXoSaVcfCU2z52yYW5qMgYxYclji8O3-2dkuS1PGryHZqMniHcSXJI1ySUiqDoB9W1AexDo0ohLx8Tmv-vyiwwZ9VMXfSERrTLu7H8LgXJsTvjEfQSJW7nK15rnPMEXoYKdgtqgW4hpzqzILoBTf-aVXc6pzNmB85GPTnzgICHEoPOMJnD5Yz9t5Rg3irwpHaick0i_JL4_-wBukc1_LTxE9ar_SoDYVzFJ6eJiVbSA0byzXqhfFVVcKFwdFr0c3QpGV6hjnBWSm7ev0azOSfso5K9ITlGiT9WVbwPeXSgjaZ8OeYzTEBhuzOp0aN6UdoILQZ9RejZSx7lU9MCz83WN5azYYiDePBOWGy1ZyMlTFZ-bltF6RRnfUgcSzPy4hrz1tn_rvIaRQcecxX_c6JkSZ5Zvf0k2BJcH5d7D37LQjEjr3yw9pXDshYxEFfIwQan3rZ1amFdOL2sksiDrWlsC-6b-duPVAloK1aK2MGAYPFF6m0bAqjKnQPLpM7kFY1b11l3eibFccEKmmplT0UlaliTgtjqrKKYM1XI5h1A_DoCL
# ...

# %% [markdown]
# Paste the access token copied from above in the below command after 'Bearer' and run the below command.

# %%
# !curl -H "Authorization: Bearer eyJraWQiOiIyMDIwMDUyNTE4MzAiLCJhbGciOiJSUzI1NiJ9.....cW9yUqwkIQdVbhRQEOFI_VQgdlxV8YBLfoCp5XQwstIEcV6Ff_rdbMEv-Tzo8Umt8Uy0MHeNXLX7uIPAxjCs5f6fQ2pZUCDw4CwV1_D_R2be9ISYj77P4iNuvHMhmZs9S2P8LuSDvEA-x7CuvVzntWEHZGaLp6tZz7NAxR8PTP1pZMPri-fKhQ6Uvn-YzcEFXBV9aqlDZuHjQtARBGo9280BdFVuCFUaDGupsC6BpVKHUvxZ1rNpZFEZeDzZEuoanHxk3EXyGwZQB2wIt-jokaG5agte7sYTuAmdCRr5CtHfA1cR6qjMe-1ndfCoZRKw5zBjtT0KHrjL3Rx3VFVaiQ" "https://iam.cloud.ibm.com/identity/token"

# %% [markdown]
# Enter the input test cases as prompted.

# %%
step = int(input("Enter step as integer value: "))#1
typee = input("Enter from the following types - 1. CASH_OUT, 2. TRANSFER: ")#'TRANSFER'
amount = float(input("Enter transaction amount in float type: "))#181.00
nameOrig = input("Enter the source account name in string starting with a capital alphabet and followed by 10 digits: ")#'C1305486145'
OldBalanceOrig = float(input("Enter source account Old balance amount in float type: "))#181.0
NewBalanceOrig = float(input("Enter source account New balance amount in float type: "))#0.00
nameDest = input("Enter the destination account name in string starting with a capital alphabet and followed by 10 digits: ")#'C553264065'
OldBalanceDest = float(input("Enter destination account Old balance amount in float type: "))#0.0
NewBalanceDest = float(input("Enter destination account New balance amount in float type: "))#0.0
isFlaggedFraud = int(input("Enter the flag value as 0 or 1: "))#0
# Out:
# Enter step as integer value: 1
# Enter from the following types - 1. CASH_OUT, 2. TRANSFER: TRANSFER
# Enter transaction amount in float type: 500.00
# Enter the source account name in string starting with a capital alphabet and followed by 10 digits:C1305486145
# Enter source account Old balance amount in float type:500.0
# Enter source account New balance amount in float type:0.00
# Enter the destination account name in string starting with a capital alphabet and followed by 10 digits:C553264065
# Enter destination account Old balance amount in float type:0.0
# Enter destination account New balance amount in float type:0.0
# Enter the flag value as 0 or 1:0

# %%
#json_values = [[1, 'TRANSFER', 181.00, 'C1305486145', 181.0, 0.00, 'C553264065', 0.00, 0.0]]

# %% [markdown]
# Paste the above copied IBM IAM access token in the iam_token variable value and run the cell below to get the predictions.

# %%
import urllib3, requests, json

iam_token = "eyJraWQiOiIyMDIwMDUyNTE4MzAiLCJhbGciOiJSUzI1NiJ9.....GzwhRp8q4S6i8DBUDr7K19iu5xUc86NdlvrQnIFbLQecYo1H18TWojD02Gh0hBcC9nDA-uW2AKVPmcv1aaHaqNbbfiHIkCmbqqZo2XTsuxHBjfbyhRuHBAOg8MBelHxvWc8c2z6H2I_lbix7VPBhG8iYH4Hx7TzQFCrZOq1RjHHogdCABoUMaRY9SrXufimjTIjoajKKkzS_t4ICKWjL-_DsF4QOpAUNAu6h4JBnJ-bIFg4PbpbVkfG4-4m2b-RPUmBv-6aeODHeCzBu_vKOxOWq8X8DaEkFKeOQJBC8Evtktk-HvGEe_umTaHwfhWlAUOnxwtyPFBIHdze49Z-Qpw"
ml_instance_id = "44e92887-8bc9-44f5-944e-6f7a15772f1e"
# NOTE: generate iam_token and retrieve ml_instance_id based on provided documentation	
header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + iam_token, 'ML-Instance-ID': ml_instance_id}

# NOTE: manually define and pass the array(s) of values to be scored in the next line
payload_scoring = {"input_data": [{"fields": ["step", "type", "amount", "nameOrig", "OldBalanceOrig", "NewBalanceOrig", "nameDest", "OldBalanceDest", "NewBalanceDest", "isFlaggedFraud"], "values": [[step, typee, amount, nameOrig, OldBalanceOrig, NewBalanceOrig, nameDest, OldBalanceDest, NewBalanceDest, isFlaggedFraud]]}]}

response_scoring = requests.post('https://eu-gb.ml.cloud.ibm.com/v4/deployments/647b4ce4-aa85-4b09-b328-94e8a654da1d/predictions', json=payload_scoring, headers=header)
print("Scoring response")
print(json.loads(response_scoring.text))
# Out:
# Scoring response
# {'predictions': [{'fields': ['prediction', 'probability'], 'values': [[1, [0.0, 1.0]]]}]}

# %% [markdown]
# ### Results - JSON value for prediction indicates results for genuine and fraud transactions.
# 	1 - Transaction is Fraud
# 	0 - Transaction is Genuine
